# %% [markdown]
# ## Merging data retrieved from Wikidata and MIMIC

# %%
# !pip install neo4j
# Out:
# Requirement already satisfied: neo4j in /usr/local/lib/python3.7/dist-packages (4.4.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from neo4j) (2022.1)

# %%
from neo4j import GraphDatabase
from neo4j import Query

# %%
class Neo4jConnection:
    
    def __init__(self, uri, user, pwd):
        self.__uri = uri
        self.__user = user
        self.__pwd = pwd
        self.__driver = None
        try:
            self.__driver = GraphDatabase.driver(self.__uri, auth=(self.__user, self.__pwd))
        except Exception as e:
            print("Failed to create the driver:", e)
        
    def close(self):
        if self.__driver is not None:
            self.__driver.close()
        
    def query(self, query, parameters=None, db=None):
        assert self.__driver is not None, "Driver not initialized!"
        session = None
        response = None
        try: 
            session = self.__driver.session(database=db) if db is not None else self.__driver.session() 
            #response = list(session.run(query, parameters))
            response = list(session.run(Query(query, timeout=1000.0), parameters))
        except Exception as e:
            print("Query failed:", e)
        finally: 
            if session is not None:
                session.close()
        return response


conn = Neo4jConnection(uri="bolt://100.26.248.51:7687", 
                       user="neo4j",              
                       pwd="pier-adaption-petroleum")

# %%
import pandas as pd 
data = pd.read_csv('final_relations.csv', index_col=0)
data.confidence = data.confidence.astype(float)
data = data[(data.relation!='o')]
data.dropna(inplace=True)
data.head(20)
# Out:
#     Unnamed: 0.1        relation    entity1  entity1_begin  entity1_end  \
# 0              0       CAUSED BY    PROBLEM           3816         3827
# 1              1   HAS TREATMENT    PROBLEM           4939         4949
# 2              2   HAS TREATMENT    PROBLEM           4939         4949
# 3              3         DETECTS       TEST           5193         5204
# 4              4  TREATS PROBLEM  TREATMENT           5345         5357
# 5              5         DETECTS       TEST           5506         5519
# 6              6         DETECTS       TEST           6181         6203
# 7              7  TREATS PROBLEM  TREATMENT           8082         8094
# 8              8   HAS TREATMENT    PROBLEM            794          820
# 9              9   HAS TREATMENT    PROBLEM            794          820
# 10            10         DETECTS       TEST           1938         1962
# 11            11         DETECTS       TEST           1938         1962
# 12            12         DETECTS       TEST           1938         1962
# 13            13     DETECTED BY    PROBLEM           3197         3204
# 14            14         DETECTS       TEST           4540         4549
# 15            15         DETECTS       TEST           6733         6752
# 16            16         DETECTS       TEST           6950         6956
# 17            17         DETECTS       TEST           7007         7013
# 18            18         DETECTS       TEST           7075         7085
# 19            19     DETECTED BY    PROBLEM           8878         8898
#
#                          chunk1    entity2  entity2_begin  entity2_end  \
# 0                  pneumothorax  TREATMENT           3839         3856
# 1                   hypotensive  TREATMENT           4955         4966
# 2                   hypotensive  TREATMENT           5003         5015
# 3                  pan cultured    PROBLEM           5220         5227
# 4                 Beta-blockers    PROBLEM           5376         5386
# 5                the chest film    PROBLEM           5528         5566
# 6       A grape juice challenge    PROBLEM           6223         6246
# 7                 Acetaminophen    PROBLEM           8193         8196
# 8   inferior lead ST-elevations  TREATMENT            833          835
# 9   inferior lead ST-elevations  TREATMENT            838          844
# 10    Cardiac review of systems    PROBLEM           1990         1996
# 11    Cardiac review of systems    PROBLEM           2011         2038
# 12    Cardiac review of systems    PROBLEM           2041         2049
# 13                     enlarged       TEST           3209         3217
# 14                   V5-V6  TEE    PROBLEM           4585         4593
# 15         Resting hemodynamics    PROBLEM           6763         6800
# 16                      The SVR    PROBLEM           6962         6969
# 17                      The PVR    PROBLEM           7019         7033
# 18                  Aortography    PROBLEM           7109         7125
# 19        RV infarct physiology       TEST           8907         8922
#
#                                      chunk2  confidence
# 0                        chest tube removal    0.906085
# 1                              the epidural    0.905324
# 2                             a fluid bolus    0.901337
# 3                                  organism    0.962884
# 4                               tachycardia    0.964870
# 5   a right lower lobe effusion/atelectasis    0.999408
# 6                  obvious anastomoses leak    0.960455
# 7                                      pain    0.997368
# 8                                       ASA    0.993174
# 9                                   heparin    0.995132
# 10                                  dyspnea    0.997523
# 11             paroxysmal nocturnal dyspnea    0.997689
# 12                                orthopnea    0.997218
# 13                                palpation    0.994372
# 14                                elongated    0.957628
# 15   elevated right sided filling pressures    0.999297
# 16                                 elevated    0.990085
# 17                          mildly elevated    0.991924
# 18                        aortic dissection    0.998285
# 19                         right heart cath    0.983076

# %%
print(len(data.index))
# Out:
# 601610

# %%
data = data[['relation', 'entity1', 'chunk1', 'entity2', 'chunk2']]
data.head()
# Out:
#          relation    entity1         chunk1    entity2              chunk2
# 0       CAUSED BY    PROBLEM   pneumothorax  TREATMENT  chest tube removal
# 1   HAS TREATMENT    PROBLEM    hypotensive  TREATMENT        the epidural
# 2   HAS TREATMENT    PROBLEM    hypotensive  TREATMENT       a fluid bolus
# 3         DETECTS       TEST   pan cultured    PROBLEM            organism
# 4  TREATS PROBLEM  TREATMENT  Beta-blockers    PROBLEM         tachycardia

# %%
data2 = pd.read_csv('health_problem_infectious_disease')
data2.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1        relation  entity1  \
# 0           0          1284   HAS TREATMENT  PROBLEM
# 1           1           377  DIAGNOSED WITH  PROBLEM
# 2           2          2240    HAS SYMPTOMS  PROBLEM
# 3           3          2601    HAS SYMPTOMS  PROBLEM
# 4           4          2816    HAS SYMPTOMS  PROBLEM
#
#                             chunk1    entity2       chunk2
# 0                       erysipelas  TREATMENT   cephalexin
# 1              coronavirus disease       TEST        ELISA
# 2        Rotaviral gastroenteritis    PROBLEM     vomiting
# 3  Crimean-Congo hemorrhagic fever    PROBLEM  tachycardia
# 4                     scrub typhus    PROBLEM     insomnia

# %%
data2 = data2[['relation', 'entity1', 'chunk1', 'entity2', 'chunk2']]
data2.head()
# Out:
#          relation  entity1                           chunk1    entity2  \
# 0   HAS TREATMENT  PROBLEM                       erysipelas  TREATMENT
# 1  DIAGNOSED WITH  PROBLEM              coronavirus disease       TEST
# 2    HAS SYMPTOMS  PROBLEM        Rotaviral gastroenteritis    PROBLEM
# 3    HAS SYMPTOMS  PROBLEM  Crimean-Congo hemorrhagic fever    PROBLEM
# 4    HAS SYMPTOMS  PROBLEM                     scrub typhus    PROBLEM
#
#         chunk2
# 0   cephalexin
# 1        ELISA
# 2     vomiting
# 3  tachycardia
# 4     insomnia

# %%
finaldata = pd.concat([data, data2], ignore_index=True, sort=False)
finaldata.head()
# Out:
#          relation    entity1         chunk1    entity2              chunk2
# 0       CAUSED BY    PROBLEM   pneumothorax  TREATMENT  chest tube removal
# 1   HAS TREATMENT    PROBLEM    hypotensive  TREATMENT        the epidural
# 2   HAS TREATMENT    PROBLEM    hypotensive  TREATMENT       a fluid bolus
# 3         DETECTS       TEST   pan cultured    PROBLEM            organism
# 4  TREATS PROBLEM  TREATMENT  Beta-blockers    PROBLEM         tachycardia

# %%
print(len(finaldata.index))
# Out:
# 608328

# %%
finaldata = finaldata.sample(frac=1).reset_index(drop=True)
finaldata.head(10)
# Out:
#          relation    entity1                           chunk1    entity2  \
# 0         DETECTS       TEST  Right upper quadrant ultrasound    PROBLEM
# 1       CAUSED BY    PROBLEM                      low calcium  TREATMENT
# 2         DETECTS       TEST                              MRI    PROBLEM
# 3  TREATS PROBLEM  TREATMENT                        urgent HD    PROBLEM
# 4   HAS TREATMENT    PROBLEM                       severe OSA  TREATMENT
# 5  TREATS PROBLEM  TREATMENT                  deep suctioning    PROBLEM
# 6         DETECTS       TEST                       Evaluation    PROBLEM
# 7         DETECTS       TEST                         CXR PA-L    PROBLEM
# 8     DETECTED BY    PROBLEM            diabetic ketoacidosis       TEST
# 9     DETECTED BY    PROBLEM                          empyema       TEST
#
#                           chunk2
# 0      sludge in the gallbladder
# 1                thyroid surgery
# 2                interval change
# 3            your high potassium
# 4                   tracheostomy
# 5     large amount of secretions
# 6  associated spinal cord injury
# 7                      pneumonia
# 8              laboratory values
# 9                 cytologic exam

# %%
finaldata.to_csv('medical_knowledge_base', sep=',')

# %%
import pandas as pd

data = pd.read_csv('medical_knowledge_base')
data.dropna(inplace=True)
data.head()
# Out:
#    Unnamed: 0        relation    entity1                           chunk1  \
# 0           0         DETECTS       TEST  Right upper quadrant ultrasound
# 1           1       CAUSED BY    PROBLEM                      low calcium
# 2           2         DETECTS       TEST                              MRI
# 3           3  TREATS PROBLEM  TREATMENT                        urgent HD
# 4           4   HAS TREATMENT    PROBLEM                       severe OSA
#
#      entity2                     chunk2
# 0    PROBLEM  sludge in the gallbladder
# 1  TREATMENT            thyroid surgery
# 2    PROBLEM            interval change
# 3    PROBLEM        your high potassium
# 4  TREATMENT               tracheostomy

# %%
print(len(data.index))
# Out:
# 608328

# %%
data = data[['relation', 'entity1', 'chunk1', 'entity2', 'chunk2']]
data.head()
# Out:
#          relation    entity1                           chunk1    entity2  \
# 0         DETECTS       TEST  Right upper quadrant ultrasound    PROBLEM
# 1       CAUSED BY    PROBLEM                      low calcium  TREATMENT
# 2         DETECTS       TEST                              MRI    PROBLEM
# 3  TREATS PROBLEM  TREATMENT                        urgent HD    PROBLEM
# 4   HAS TREATMENT    PROBLEM                       severe OSA  TREATMENT
#
#                       chunk2
# 0  sludge in the gallbladder
# 1            thyroid surgery
# 2            interval change
# 3        your high potassium
# 4               tracheostomy
