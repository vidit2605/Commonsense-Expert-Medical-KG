# %% [markdown]
# ## Relation Extraction

# %%
import json

with open('spark_nlp_for_healthcare_spark_ocr_4210.json', 'r') as f:
    license_keys = json.load(f)

# %%
# Defining license key-value pairs as local variables
locals().update(license_keys)

# Adding license key-value pairs to environment variables
import os
os.environ.update(license_keys)

# %%
# Installing pyspark and spark-nlp
! pip install --upgrade -q pyspark==3.1.2 spark-nlp==$PUBLIC_VERSION

# Installing Spark NLP Healthcare
! pip install --upgrade -q spark-nlp-jsl==$JSL_VERSION  --extra-index-url https://pypi.johnsnowlabs.com/$SECRET

# Installing Spark NLP Display Library for visualization
! pip install -q spark-nlp-display
# Out:
# /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes

# %%
# if you want to start the session with custom params as in start function above
from pyspark.sql import SparkSession

def start(SECRET):
    builder = SparkSession.builder \
        .appName("Spark NLP Licensed") \
        .master("local[*]") \
        .config("spark.driver.memory", "16G") \
        .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer") \
        .config("spark.kryoserializer.buffer.max", "2000M") \
        .config("spark.jars.packages", "com.johnsnowlabs.nlp:spark-nlp_2.12:"+PUBLIC_VERSION) \
        .config("spark.jars", "https://pypi.johnsnowlabs.com/"+SECRET+"/spark-nlp-jsl-"+JSL_VERSION+".jar")
      
    return builder.getOrCreate()

# %%
import json
import os
from pyspark.ml import Pipeline,PipelineModel
from pyspark.sql import SparkSession

from sparknlp.annotator import *
from sparknlp_jsl.annotator import *
from sparknlp.base import *
import sparknlp_jsl
import sparknlp

import warnings
warnings.filterwarnings('ignore')

params = {"spark.driver.memory":"16G", 
          "spark.kryoserializer.buffer.max":"2000M", 
          "spark.driver.maxResultSize":"2000M"} 

spark = sparknlp_jsl.start(license_keys['SECRET'],params=params)

print ("Spark NLP Version :", sparknlp.version())
print ("Spark NLP_JSL Version :", sparknlp_jsl.version())
# Out:
# Warning::Spark Session already created, some configs may not take.
# Spark NLP Version : 3.4.1
# Spark NLP_JSL Version : 3.4.1

# %%
import functools 
import numpy as np
from scipy import spatial
import pyspark.sql.functions as F
import pyspark.sql.types as T
from sparknlp.base import *

# %%
documenter = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

sentencer = SentenceDetector()\
    .setInputCols(["document"])\
    .setOutputCol("sentences")

tokenizer = sparknlp.annotators.Tokenizer()\
    .setInputCols(["sentences"])\
    .setOutputCol("tokens")

words_embedder = WordEmbeddingsModel()\
    .pretrained("embeddings_clinical", "en", "clinical/models")\
    .setInputCols(["sentences", "tokens"])\
    .setOutputCol("embeddings")

pos_tagger = PerceptronModel()\
    .pretrained("pos_clinical", "en", "clinical/models") \
    .setInputCols(["sentences", "tokens"])\
    .setOutputCol("pos_tags")
# Out:
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# pos_clinical download started this may take some time.
# Approximate size to download 1.5 MB
# [OK!]

# %%
ner_chunker = NerConverterInternal()\
    .setInputCols(["sentences", "tokens", "ner_tags"])\
    .setOutputCol("ner_chunks")

dependency_parser = DependencyParserModel()\
    .pretrained("dependency_conllu", "en")\
    .setInputCols(["sentences", "pos_tags", "tokens"])\
    .setOutputCol("dependencies")
# Out:
# dependency_conllu download started this may take some time.
# Approximate size to download 16.7 MB
# [OK!]

# %%
import pandas as pd

def get_relations_df (results, col='relations'):
    rel_pairs=[]
    for rel in results[0][col]:
        rel_pairs.append((
          rel.result, 
          rel.metadata['entity1'], 
          rel.metadata['entity1_begin'],
          rel.metadata['entity1_end'],
          rel.metadata['chunk1'], 
          rel.metadata['entity2'],
          rel.metadata['entity2_begin'],
          rel.metadata['entity2_end'],
          rel.metadata['chunk2'], 
          rel.metadata['confidence']
        ))

    rel_df = pd.DataFrame(rel_pairs, columns=['relation','entity1','entity1_begin','entity1_end','chunk1','entity2','entity2_begin','entity2_end','chunk2', 'confidence'])

    return rel_df

# %%
text ="""Radiologic studies also included a chest
CT, which confirmed cavitary lesions in the left lung apex
consistent with infectious process/tuberculosis.
"""

lmodel = LightPipeline(model)
annotations = lmodel.fullAnnotate(text)

rel_df = get_relations_df (annotations)

rel_df[rel_df.relation!="O"]
# Out:
# Empty DataFrame
# Columns: [relation, entity1, entity1_begin, entity1_end, chunk1, entity2, entity2_begin, entity2_end, chunk2, confidence]
# Index: []

# %%
text ="""RADIOLOGIC STUDIES:  Radiologic studies also included a chest
CT, which confirmed cavitary lesions in the left lung apex
consistent with infectious process/tuberculosis.  This also
moderate-sized left pleural effusion.

HEAD CT:  Head CT showed no intracranial hemorrhage or mass
effect, but old infarction consistent with past medical
history.

ABDOMINAL CT:  Abdominal CT showed lesions of T10 and sacrum most likely secondary to osteoporosis. These can be followed by repeat imaging as an outpatient.

"""

lmodel = LightPipeline(model)
annotations = lmodel.fullAnnotate(text)

rel_df = get_relations_df(annotations)

rel_df[rel_df.relation!="O"]
# Out:
#   relation entity1 entity1_begin entity1_end        chunk1  entity2  \
# 0     TeRP    TEST           220         226       HEAD CT  PROBLEM
# 1     TeRP    TEST           230         236       Head CT  PROBLEM
# 2     TeRP    TEST           230         236       Head CT  PROBLEM
# 3     TeRP    TEST           361         372  Abdominal CT  PROBLEM
#
#   entity2_begin entity2_end                     chunk2  confidence
# 0           248         270    intracranial hemorrhage  0.99999976
# 1           248         270    intracranial hemorrhage         1.0
# 2           292         305             old infarction   0.9972275
# 3           381         405  lesions of T10 and sacrum         1.0

# %%
rel_df
# Out:
# Empty DataFrame
# Columns: [relation, entity1, entity1_begin, entity1_end, chunk1, entity2, entity2_begin, entity2_end, chunk2, confidence]
# Index: []

# %%
clinical_ner_tagger = MedicalNerModel.pretrained("ner_clinical", "en", "clinical/models")\
    .setInputCols("sentences", "tokens", "embeddings")\
    .setOutputCol("ner_tags")    

clinical_re_ner_chunk_filter = RENerChunksFilter() \
    .setInputCols(["ner_chunks", "dependencies"])\
    .setOutputCol("re_ner_chunks")\
    .setMaxSyntacticDistance(4)\
    .setRelationPairs(["problem-test", "problem-treatment"])# we can set the possible relation pairs (if not set, all the relations will be calculated)
    
clinical_re_Model = RelationExtractionDLModel() \
    .pretrained('redl_clinical_biobert', "en", "clinical/models")\
    .setPredictionThreshold(0.9)\
    .setInputCols(["re_ner_chunks", "sentences"]) \
    .setOutputCol("relations")

pipeline = Pipeline(stages=[
    documenter,
    sentencer,
    tokenizer, 
    words_embedder, 
    pos_tagger, 
    clinical_ner_tagger,
    ner_chunker,
    dependency_parser,
    clinical_re_ner_chunk_filter,
    clinical_re_Model
])

empty_data = spark.createDataFrame([[""]]).toDF("text")
model = pipeline.fit(empty_data)
# Out:
# ner_clinical download started this may take some time.
# Approximate size to download 13.9 MB
# [OK!]
# redl_clinical_biobert download started this may take some time.
# Approximate size to download 383.4 MB
# [OK!]

# %%
import pandas as pd

# %%
#importing the file with discharge summaries
df = pd.read_csv("discharge_df.csv")

# %%
df.head()
# Out:
#    Unnamed: 0           CATEGORY  \
# 0           0  Discharge summary
# 1           1  Discharge summary
# 2           2  Discharge summary
# 3           3  Discharge summary
# 4           4  Discharge summary
#
#                                                 TEXT
# 0  Admission Date:  [**2151-7-16**]       Dischar...
# 1  Admission Date:  [**2118-6-2**]       Discharg...
# 2  Admission Date:  [**2119-5-4**]              D...
# 3  Admission Date:  [**2124-7-21**]              ...
# 4  Admission Date:  [**2162-3-3**]              D...

# %%
len(df)
# Out:
# 59652

# %%
df["TEXT"][0]
# Out:
# 'Admission Date:  [**2151-7-16**]       Discharge Date:  [**2151-8-4**]\n\n\nService:\nADDENDUM:\n\nRADIOLOGIC STUDIES:  Radiologic studies also included a chest\nCT, which confirmed cavitary lesions in the left lung apex\nconsistent with infectious process/tuberculosis.  This also\nmoderate-sized left pleural effusion.\n\nHEAD CT:  Head CT showed no intracranial hemorrhage or mass\neffect, but old infarction consistent with past medical\nhistory.\n\nABDOMINAL CT:  Abdominal CT showed lesions of\nT10 and sacrum most likely secondary to osteoporosis. These can\nbe followed by repeat imaging as an outpatient.\n\n\n\n                            [**First Name8 (NamePattern2) **] [**First Name4 (NamePattern1) 1775**] [**Last Name (NamePattern1) **], M.D.  [**MD Number(1) 1776**]\n\nDictated By:[**Hospital 1807**]\nMEDQUIST36\n\nD:  [**2151-8-5**]  12:11\nT:  [**2151-8-5**]  12:21\nJOB#:  [**Job Number 1808**]\n'

# %%
annotations = lmodel.fullAnnotate((df["TEXT"][0]).replace("\n", " "))
rel_df = get_relations_df (annotations)

rel_df = rel_df[(rel_df.relation!="O")]

rel_df
# Out:
#   relation entity1 entity1_begin entity1_end        chunk1  entity2  \
# 0     TeRP    TEST           313         319       HEAD CT  PROBLEM
# 1     TeRP    TEST           323         329       Head CT  PROBLEM
# 2     TeRP    TEST           323         329       Head CT  PROBLEM
# 3     TeRP    TEST           454         465  Abdominal CT  PROBLEM
#
#   entity2_begin entity2_end                     chunk2  confidence
# 0           341         363    intracranial hemorrhage   0.9948571
# 1           341         363    intracranial hemorrhage  0.99840754
# 2           385         398             old infarction  0.99830353
# 3           474         498  lesions of T10 and sacrum  0.99864763

# %%
rel_df.columns
# Out:
# Index(['relation', 'entity1', 'entity1_begin', 'entity1_end', 'chunk1',
#        'entity2', 'entity2_begin', 'entity2_end', 'chunk2', 'confidence'],
#       dtype='object')

# %%
column_names = ['relation', 'entity1', 'entity1_begin', 'entity1_end', 'chunk1',
       'entity2', 'entity2_begin', 'entity2_end', 'chunk2', 'confidence']

# %%
relation_df = pd.DataFrame(columns = column_names)

# %%
relation_df
# Out:
# Empty DataFrame
# Columns: [relation, entity1, entity1_begin, entity1_end, chunk1, entity2, entity2_begin, entity2_end, chunk2, confidence]
# Index: []

# %%
from tqdm import tqdm as tq
import time

# ner_results = []

#range can be changed as required
for a in tq(range(50000,59652)):
    annotations = lmodel.fullAnnotate((df.loc[a, "TEXT"]).replace("\n", " "))
    rel_df = get_relations_df (annotations)

    rel_df = rel_df[(rel_df.relation!="O")]
#     print(len(rel_df))
    if len(rel_df)!=0:
        relation_df = relation_df.append(rel_df,ignore_index=True)
# Out:
# 100%|██████████| 9652/9652 [14:16:52<00:00,  5.33s/it]

# %%
relation_df
# Out:
#        relation    entity1 entity1_begin entity1_end               chunk1  \
# 0          TeRP       TEST          1064        1070              an XRay
# 1          TeRP       TEST          1124        1133           Basic labs
# 2          TeRP       TEST          1472        1474                  EKG
# 3          TrAP    PROBLEM          1483        1486                 LBBB
# 4          TeRP       TEST          6061        6067              CT head
# ...         ...        ...           ...         ...                  ...
# 109632     TeCP    PROBLEM          9657        9675  infectious diseases
# 109633     TeRP       TEST           764         774          examination
# 109634     TeRP    PROBLEM          2816        2832    an ongoing anemia
# 109635     TrAP    PROBLEM          3479        3492       your incisions
# 109636     TrAP  TREATMENT          3531        3539            ointments
#
#           entity2 entity2_begin entity2_end                           chunk2  \
# 0         PROBLEM          1092        1121   a closed fracture of the femur
# 1         PROBLEM          1161        1175                  baseline anemia
# 2         PROBLEM          1483        1486                             LBBB
# 3       TREATMENT          1518        1525                         Morphine
# 4         PROBLEM          6103        6131    acute intracranial hemorrhage
# ...           ...           ...         ...                              ...
# 109632       TEST          9681        9711  monitoring of your blood counts
# 109633    PROBLEM           794         798                            rales
# 109634       TEST          2839        2849                      hematocrits
# 109635  TREATMENT          3531        3539                        ointments
# 109636    PROBLEM          3544        3552                        incisions
#
#         confidence
# 0        0.9973917
# 1       0.99217427
# 2       0.99847513
# 3        0.9915821
# 4        0.9977088
# ...            ...
# 109632  0.94961625
# 109633   0.9989237
# 109634  0.92045087
# 109635     0.94121
# 109636   0.9085855
#
# [109637 rows x 10 columns]

# %%
from tqdm import tqdm as tq
import time

ner_results = []
for a in tq(range(1)):
    annotations = lmodel.fullAnnotate(text)
    rel_df = get_relations_df (annotations)

    rel_df = rel_df[(rel_df.relation!="O")]
# #     print(len(rel_df))
#     if len(rel_df)!=0:
#         relation_df = relation_df.append(rel_df,ignore_index=True)
# Out:
# 100%|██████████| 1/1 [09:50<00:00, 590.23s/it]

# %%
rel_df
# Out:
#     relation    entity1 entity1_begin entity1_end  \
# 0       TeRP       TEST           313         319
# 1       TeRP       TEST           323         329
# 2       TeRP       TEST           323         329
# 3       TeRP       TEST           454         465
# 6       TeRP       TEST          1779        1795
# ..       ...        ...           ...         ...
# 437     TrAP    PROBLEM        194023      194044
# 438     TrCP    PROBLEM        194670      194697
# 439     TrAP  TREATMENT        195923      195927
# 440     TrAP  TREATMENT        196410      196417
# 441     TrAP  TREATMENT        196410      196417
#
#                            chunk1    entity2 entity2_begin entity2_end  \
# 0                         HEAD CT    PROBLEM           341         363
# 1                         Head CT    PROBLEM           341         363
# 2                         Head CT    PROBLEM           385         398
# 3                    Abdominal CT    PROBLEM           474         498
# 6               Review of systems    PROBLEM          1829        1834
# ..                            ...        ...           ...         ...
# 437        Chronic left knee pain  TREATMENT        194081      194115
# 438  2+ pitting edema b/l Strings  TREATMENT        194704      194708
# 439                         PRBCs    PROBLEM        195933      195955
# 440                      coumadin    PROBLEM        196432      196433
# 441                      coumadin    PROBLEM        196439      196454
#
#                                   chunk2  confidence
# 0                intracranial hemorrhage  0.99725145
# 1                intracranial hemorrhage  0.99826175
# 2                         old infarction   0.9983309
# 3              lesions of T10 and sacrum  0.99946445
# 6                                 Fevers   0.9946861
# ..                                   ...         ...
# 437  debridement of left knee [**2123**]   0.9693431
# 438                                seton   0.9560664
# 439              borderline urine output  0.95823085
# 440                                   PE   0.9911623
# 441                     cardiac thrombus   0.9804437
#
# [350 rows x 10 columns]

# %%
relation_df
# Out:
#     relation    entity1 entity1_begin entity1_end           chunk1    entity2  \
# 0       TeRP       TEST           313         319          HEAD CT    PROBLEM
# 1       TeRP       TEST           323         329          Head CT    PROBLEM
# 2       TeRP       TEST           323         329          Head CT    PROBLEM
# 3       TeRP       TEST           454         465     Abdominal CT    PROBLEM
# 4       TrAP    PROBLEM           253         261        emphysema  TREATMENT
# ..       ...        ...           ...         ...              ...        ...
# 141     TrAP  TREATMENT           895         903        resection    PROBLEM
# 142     TrAP    PROBLEM          1066        1080  a wound washout  TREATMENT
# 143     TrAP  TREATMENT          1228        1240    radio therapy    PROBLEM
# 144     TrAP  TREATMENT          3774        3786    Acetaminophen    PROBLEM
# 145     TrAP  TREATMENT          4124        4136    Hydromorphone    PROBLEM
#
#     entity2_begin entity2_end                     chunk2  confidence
# 0             341         363    intracranial hemorrhage   0.9966468
# 1             341         363    intracranial hemorrhage   0.9990114
# 2             385         398             old infarction    0.998779
# 3             474         498  lesions of T10 and sacrum  0.99928623
# 4             271         277                    home O2  0.91821116
# ..            ...         ...                        ...         ...
# 141           908         924          the radionecrosis   0.9967272
# 142          1086        1096                craniectomy   0.9099828
# 143          1246        1248                        avm   0.9863196
# 144          3856        3868              pain/t>100/HA   0.9954633
# 145          4204        4207                       pain   0.9962845
#
# [146 rows x 10 columns]

# %%
relation_df["relation"].unique()
# Out:
# array(['TeRP', 'TrAP', 'TrCP', 'TeCP', 'TrIP', 'PIP', 'TrNAP', 'TrWP'],
#       dtype=object)

# %%
relation_df.to_csv("/home/akumar/relations-8.csv")
